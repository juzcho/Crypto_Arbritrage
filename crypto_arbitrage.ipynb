# %% [markdown]
# ## Crypto Arbitrage
#
# In this Challenge, you'll take on the role of an analyst at a high-tech investment firm. The vice president (VP) of your department is considering arbitrage opportunities in Bitcoin and other cryptocurrencies. As Bitcoin trades on markets across the globe, can you capitalize on simultaneous price dislocations in those markets by using the powers of Pandas?
#
# For this assignment, you’ll sort through historical trade data for Bitcoin on two exchanges: Bitstamp and Coinbase. Your task is to apply the three phases of financial analysis to determine if any arbitrage opportunities exist for Bitcoin.
#
# This aspect of the Challenge will consist of 3 phases.
#
# 1. Collect the data.
#
# 2. Prepare the data.
#
# 3. Analyze the data.

# %% [markdown]
# ###  Import the required libraries and dependencies.

# %%
import pandas as pd
from pathlib import Path
# %matplotlib inline

# %% [markdown]
# ## Collect the Data
#
# To collect the data that you’ll need, complete the following steps:
#
# Instructions.
#
# 1. Using the Pandas `read_csv` function and the `Path` module, import the data from `bitstamp.csv` file, and create a DataFrame called `bitstamp`. Set the DatetimeIndex as the Timestamp column, and be sure to parse and format the dates.
#
# 2. Use the `head` (and/or the `tail`) function to confirm that Pandas properly imported the data.
#
# 3. Repeat Steps 1 and 2 for `coinbase.csv` file.

# %% [markdown]
# ### Step 1: Using the Pandas `read_csv` function and the `Path` module, import the data from `bitstamp.csv` file, and create a DataFrame called `bitstamp`. Set the DatetimeIndex as the Timestamp column, and be sure to parse and format the dates.

# %%
# Read in the CSV file called "bitstamp.csv" using the Path module. 
# The CSV file is located in the Resources folder.
# Set the index to the column "Date"
# Set the parse_dates and infer_datetime_format parameters

# This should allow us to read the bitstamp.csv file using Path. 
# We are also using its Timestamp as its index column. -OK

df_bitstamp = pd.read_csv(Path('./Resources/bitstamp.csv'), 
    index_col = "Timestamp",
    parse_dates = True,
    infer_datetime_format = True
    )

# %% [markdown]
# ### Step 2: Use the `head` (and/or the `tail`) function to confirm that Pandas properly imported the data.

# %%
# Use the head (and/or tail) function to confirm that the data was imported properly.
# YOUR CODE HERE -OK

# %%
df_bitstamp.head() # This shows the bitstamp.csv top 5 rows.
# Out:
#                          Open      High       Low      Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13681.04  13681.04  13637.93  $13646.48    3.334553
# 2018-01-01 00:01:00  13646.48  13658.75  13610.18  $13658.75    2.663188
# 2018-01-01 00:02:00  13616.93  13616.93  13610.06  $13610.22    0.084653
# 2018-01-01 00:03:00  13610.27  13639.09  13610.27  $13639.09    7.182986
# 2018-01-01 00:04:00  13635.35  13636.35  13620.00   $13620.0    1.069665
#
#                        USD Volume  Weighted Price
# Timestamp
# 2018-01-01 00:00:00  45482.128785    13639.647479
# 2018-01-01 00:01:00  36361.390888    13653.332816
# 2018-01-01 00:02:00   1152.144036    13610.136247
# 2018-01-01 00:03:00  97856.416478    13623.361128
# 2018-01-01 00:04:00  14582.660932    13632.923329

# %%
df_bitstamp.tail() # This shows the bitstamp.csv last 5 rows.
# Out:
#                         Open     High      Low     Close  BTC Volume  \
# Timestamp
# 2018-03-31 23:55:00  6935.01  6939.07  6922.56  $6922.56    1.044354
# 2018-03-31 23:56:00  6922.02  6922.02  6918.00  $6920.32    3.069539
# 2018-03-31 23:57:00  6920.33  6936.42  6920.33  $6934.72   28.239049
# 2018-03-31 23:58:00  6927.65  6929.42  6927.65  $6927.65    0.839507
# 2018-03-31 23:59:00  6929.98  6929.98  6928.00  $6928.01    0.209363
#
#                         USD Volume  Weighted Price
# Timestamp
# 2018-03-31 23:55:00    7240.034602     6932.550078
# 2018-03-31 23:56:00   21245.076275     6921.260233
# 2018-03-31 23:57:00  195789.408220     6933.286106
# 2018-03-31 23:58:00    5817.007705     6929.080007
# 2018-03-31 23:59:00    1450.735763     6929.289993

# %% [markdown]
# ### Step 3: Repeat Steps 1 and 2 for `coinbase.csv` file.

# %%
# Read in the CSV file called "coinbase.csv" using the Path module. 
# The CSV file is located in the Resources folder.
# Set the index to the column "Timestamp"
# Set the parse_dates and infer_datetime_format parameters

# This should allow us to read the coinbase.csv file using Path. 
# We are also using its Timestamp as its index column. -OK

df_coinbase = pd.read_csv(Path('./Resources/coinbase.csv'), 
    index_col = "Timestamp",
    parse_dates = True,
    infer_datetime_format = True
    )

# %%
# Use the head (and/or tail) function to confirm that the data was imported properly.
# YOUR CODE HERE -OK

# %%
df_coinbase.head() # This shows the coinbase.csv top 5 rows.
# Out:
#                          Open      High       Low      Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13620.00  13620.00  13608.49  $13608.49   20.812754
# 2018-01-01 00:01:00  13607.14  13607.14  13601.66  $13601.66   13.474359
# 2018-01-01 00:02:00  13601.44  13601.44  13580.00   $13580.0   11.536360
# 2018-01-01 00:03:00  13587.31  13587.31  13542.70  $13550.34   16.328039
# 2018-01-01 00:04:00  13550.34  13585.95  13550.34  $13583.44    9.955364
#
#                        USD Volume  Weighted Price
# Timestamp
# 2018-01-01 00:00:00  283451.08537    13619.105106
# 2018-01-01 00:01:00  183283.97801    13602.426919
# 2018-01-01 00:02:00  156789.19686    13590.872506
# 2018-01-01 00:03:00  221413.64182    13560.332806
# 2018-01-01 00:04:00  135141.26944    13574.719401

# %%
df_coinbase.tail() # This shows the coinbase.csv last 5 rows.
# Out:
#                         Open     High      Low     Close  BTC Volume  \
# Timestamp
# 2018-03-31 23:55:00  6945.20  6948.06  6930.00   $6930.0    5.802288
# 2018-03-31 23:56:00  6930.00  6930.01  6930.00  $6930.01    0.625053
# 2018-03-31 23:57:00  6930.01  6933.91  6930.01  $6933.91    0.776431
# 2018-03-31 23:58:00  6933.91  6938.00  6933.90  $6937.31    0.133413
# 2018-03-31 23:59:00  6937.30  6937.30  6931.09   $6934.0    1.012720
#
#                        USD Volume  Weighted Price
# Timestamp
# 2018-03-31 23:55:00  40243.918480     6935.869979
# 2018-03-31 23:56:00   4331.620701     6930.005567
# 2018-03-31 23:57:00   5382.532162     6932.405747
# 2018-03-31 23:58:00    925.356547     6936.048538
# 2018-03-31 23:59:00   7022.275088     6934.070316

# %% [markdown]
# ## Prepare the Data
#
# To prepare and clean your data for analysis, complete the following steps:
#
# 1. For the bitstamp DataFrame, replace or drop all `NaN`, or missing, values in the DataFrame.
#
# 2. Use the `str.replace` function to remove the dollar signs ($) from the values in the Close column.
#
# 3. Convert the data type of the Close column to a `float`.
#
# 4. Review the data for duplicated values, and drop them if necessary.
#
# 5. Repeat Steps 1–4 for the coinbase DataFrame.

# %% [markdown]
# ### Step 1: For the bitstamp DataFrame, replace or drop all `NaN`, or missing, values in the DataFrame. -OK

# %%
# For the bitstamp DataFrame, replace or drop all NaNs or missing values in the DataFrame
# YOUR CODE HERE -OK

# Dropping all NaNs
# This will remove all the data with a NaN value or a missing value.
df_drop_bitstamp = df_bitstamp.dropna()

# %% [markdown]
# ### Step 2: Use the `str.replace` function to remove the dollar signs ($) from the values in the Close column.

# %%
# Use the str.replace function to remove the dollar sign, $
# YOUR CODE HERE - OK

# We use .loc to first locate the Close column,
# then we use str.replace to remove all $.
df_drop_bitstamp.loc[:, "Close"] = df_drop_bitstamp.loc[:, "Close"].str.replace("$", "")
# Out:
# /Users/juzcho/opt/anaconda3/envs/dev/lib/python3.8/site-packages/pandas/core/indexing.py:1745: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %%
# This shows that the data "drop_bitstamp" has been cleaned 
# and $ has been removed.
df_drop_bitstamp
# Out:
#                          Open      High       Low     Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13681.04  13681.04  13637.93  13646.48    3.334553
# 2018-01-01 00:01:00  13646.48  13658.75  13610.18  13658.75    2.663188
# 2018-01-01 00:02:00  13616.93  13616.93  13610.06  13610.22    0.084653
# 2018-01-01 00:03:00  13610.27  13639.09  13610.27  13639.09    7.182986
# 2018-01-01 00:04:00  13635.35  13636.35  13620.00   13620.0    1.069665
# ...                       ...       ...       ...       ...         ...
# 2018-03-31 23:55:00   6935.01   6939.07   6922.56   6922.56    1.044354
# 2018-03-31 23:56:00   6922.02   6922.02   6918.00   6920.32    3.069539
# 2018-03-31 23:57:00   6920.33   6936.42   6920.33   6934.72   28.239049
# 2018-03-31 23:58:00   6927.65   6929.42   6927.65   6927.65    0.839507
# 2018-03-31 23:59:00   6929.98   6929.98   6928.00   6928.01    0.209363
#
#                         USD Volume  Weighted Price
# Timestamp
# ...

# %% [markdown]
# ### Step 3: Convert the data type of the Close column to a `float`.

# %%
# Convert the Close data type to a float
# YOUR CODE HERE - OK
 
# The astype will change the datatype of all data under Close column 
# to a float. 
df_drop_bitstamp.loc[:, "Close"] = df_drop_bitstamp.loc[:, "Close"].astype("float")
# Out:
# /Users/juzcho/opt/anaconda3/envs/dev/lib/python3.8/site-packages/pandas/core/indexing.py:1745: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %%
# This will show the datatypes of all the data on df_drop_bitstamp, 
# and we can see that Close column is now a float, before it was an object.

#df_drop_bitstamp.dtypes

# %% [markdown]
# ### Step 4: Review the data for duplicated values, and drop them if necessary.

# %%
# Review the data for duplicate values, and drop them if necessary
# YOUR CODE HERE

# There are no duplicated values for the data.
df_drop_bitstamp.duplicated()
# Out:
# Timestamp
# 2018-01-01 00:00:00    False
# 2018-01-01 00:01:00    False
# 2018-01-01 00:02:00    False
# 2018-01-01 00:03:00    False
# 2018-01-01 00:04:00    False
#                        ...
# 2018-03-31 23:55:00    False
# 2018-03-31 23:56:00    False
# 2018-03-31 23:57:00    False
# 2018-03-31 23:58:00    False
# 2018-03-31 23:59:00    False
# Length: 129067, dtype: bool

# %%
 # This will check for the total duplicated values.
df_drop_bitstamp.duplicated().sum()
# Out:
# 0

# %%
df_coinbase.isnull().sum()
# Out:
# Open              218
# High              218
# Low               218
# Close               0
# BTC Volume        218
# USD Volume        218
# Weighted Price    218
# dtype: int64

# %% [markdown]
# ### Step 5: Repeat Steps 1–4 for the coinbase DataFrame.

# %%
# Repeat Steps 1–4 for the coinbase DataFrame
# YOUR CODE HERE

# This will remove all NaN or missing values. 
df_drop_coinbase = df_coinbase.dropna()

# %%
df_drop_coinbase.tail(9741)
# Out:
#                         Open     High      Low     Close  BTC Volume  \
# Timestamp
# 2018-03-25 05:36:00  8532.39  8532.39  8532.38  $8532.38    0.091448
# 2018-03-25 05:37:00  8532.39  8532.39  8532.39  $8532.39    0.545742
# 2018-03-25 05:38:00  8532.39  8532.39  8532.39  $8532.39    0.381901
# 2018-03-25 05:39:00  8532.39  8532.39  8532.38  $8532.39    0.183306
# 2018-03-25 05:41:00  8532.39  8532.39  8532.38  $8532.38    0.299516
# ...                      ...      ...      ...       ...         ...
# 2018-03-31 23:55:00  6945.20  6948.06  6930.00   $6930.0    5.802288
# 2018-03-31 23:56:00  6930.00  6930.01  6930.00  $6930.01    0.625053
# 2018-03-31 23:57:00  6930.01  6933.91  6930.01  $6933.91    0.776431
# 2018-03-31 23:58:00  6933.91  6938.00  6933.90  $6937.31    0.133413
# 2018-03-31 23:59:00  6937.30  6937.30  6931.09   $6934.0    1.012720
#
#                        USD Volume  Weighted Price
# Timestamp
# 2018-03-25 05:36:00    780.270151     8532.389781
# ...

# %%
# We use .loc to first locate the Close column,
# then we use str.replace to remove all $.
df_drop_coinbase.loc[:, "Close"] = df_drop_coinbase.loc[:, "Close"].str.replace("$", "")
# Out:
# /Users/juzcho/opt/anaconda3/envs/dev/lib/python3.8/site-packages/pandas/core/indexing.py:1745: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %%
# The astype will change the datatype of all data under Close column 
# to a float.
df_drop_coinbase.loc[:, "Close"] = df_drop_coinbase.loc[:, "Close"].astype("float")

# %%
# We show the datatypes of all the data on df_drop_coinbase, 
# and we can see that Close column is now a float, before it was an object.

# df_drop_coinbase.dtypes

# %%
# There are no duplicated values for the coinbase.csv data.
df_drop_coinbase.duplicated()
# Out:
# Timestamp
# 2018-01-01 00:00:00    False
# 2018-01-01 00:01:00    False
# 2018-01-01 00:02:00    False
# 2018-01-01 00:03:00    False
# 2018-01-01 00:04:00    False
#                        ...
# 2018-03-31 23:55:00    False
# 2018-03-31 23:56:00    False
# 2018-03-31 23:57:00    False
# 2018-03-31 23:58:00    False
# 2018-03-31 23:59:00    False
# Length: 129322, dtype: bool

# %%
# This will check for the total duplicated values.
df_drop_coinbase.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Analyze the Data
#
# Your analysis consists of the following tasks:
#
# 1. Choose the columns of data on which to focus your analysis.
#
# 2. Get the summary statistics and plot the data.
#
# 3. Focus your analysis on specific dates.
#
# 4. Calculate the arbitrage profits.

# %% [markdown]
# ### Step 1: Choose columns of data on which to focus your analysis.
#
# Select the data you want to analyze. Use `loc` or `iloc` to select the following columns of data for both the bitstamp and coinbase DataFrames:
#
# * Timestamp (index)
#
# * Close

# %%
# Use loc or iloc to select `Timestamp (the index)` and `Close` from bitstamp DataFrame
# Review the first five rows of the DataFrame
# YOUR CODE HERE

# This will filter the bitstamp's 'Close' column as a data with its respective Timestamp.
bitstamp_sliced = df_drop_bitstamp.loc[:, "Close"]
bitstamp_sliced.head()
# Out:
# Timestamp
# 2018-01-01 00:00:00    13646.48
# 2018-01-01 00:01:00    13658.75
# 2018-01-01 00:02:00    13610.22
# 2018-01-01 00:03:00    13639.09
# 2018-01-01 00:04:00    13620.00
# Name: Close, dtype: float64

# %%
# Use loc or iloc to select `Timestamp (the index)` and `Close` from coinbase DataFrame

# This will filter the coinbase's 'Close' column as a data with its respective Timestamp.

coinbase_sliced = df_drop_coinbase.loc[:, "Close"]

# Review the first five rows of the DataFrame
# YOUR CODE HERE
coinbase_sliced.head()
# Out:
# Timestamp
# 2018-01-01 00:00:00    13608.49
# 2018-01-01 00:01:00    13601.66
# 2018-01-01 00:02:00    13580.00
# 2018-01-01 00:03:00    13550.34
# 2018-01-01 00:04:00    13583.44
# Name: Close, dtype: float64

# %% [markdown]
# ### Step 2: Get summary statistics and plot the data.
#
# Sort through the time series data associated with the bitstamp and coinbase DataFrames to identify potential arbitrage opportunities. To do so, complete the following steps:
#
# 1. Generate the summary statistics for each DataFrame by using the `describe` function.
#
# 2. For each DataFrame, create a line plot for the full period of time in the dataset. Be sure to tailor the figure size, title, and color to each visualization.
#
# 3. In one plot, overlay the visualizations that you created in Step 2 for bitstamp and coinbase. Be sure to adjust the legend and title for this new visualization.
#
# 4. Using the `loc` and `plot` functions, plot the price action of the assets on each exchange for different dates and times. Your goal is to evaluate how the spread between the two exchanges changed across the time period that the datasets define. Did the degree of spread change as time progressed?

# %%
# Generate the summary statistics for the bitstamp DataFrame
# YOUR CODE HERE

# This will show the statistics of the bitstamp data particularly just for the Close column.
bitstamp_sliced.describe()
# Out:
# count    129067.000000
# mean      10459.842453
# std        2315.976088
# min        5944.000000
# 25%        8613.370000
# 50%       10145.950000
# 75%       11444.810000
# max       17234.980000
# Name: Close, dtype: float64

# %%
# Generate the summary statistics for the coinbase DataFrame
# YOUR CODE HERE

# This will show the statistics of the coinbase data particularly just for the Close column.
coinbase_sliced.describe()
# Out:
# count    129322.000000
# mean      10449.140958
# std        2317.197419
# min        5882.310000
# 25%        8609.230000
# 50%       10137.440000
# 75%       11397.237500
# max       17177.990000
# Name: Close, dtype: float64

# %%
# Create a line plot for the bitstamp DataFrame for the full length of time in the dataset 
# Be sure that the figure size, title, and color are tailored to each visualization
# YOUR CODE HERE

# This creates a line plot of Bitstamp's Close column data from January 1, 2018 to March 31, 2018,
# and we have added a y-axis and labelled it to "Prices ($)".
(bitstamp_sliced.plot(kind="line", figsize=(15, 8), color=["red"], title= "Bitstamp Closing Prices").set(ylabel="Prices ($)"))
# Out:
# [Text(0, 0.5, 'Prices ($)')]

# %%
# Create a line plot for the coinbase DataFrame for the full length of time in the dataset 
# Be sure that the figure size, title, and color are tailored to each visualization
# YOUR CODE HERE

# This creates a line plot of Coinbase's Close column data from January 1, 2018 to March 31, 2018,
# and we have added a y-axis and labelled it to "Prices ($)".
(coinbase_sliced.plot(kind="line", figsize=(15, 8), color=["blue"], title= "Coinbase Closing Prices").set(ylabel="Prices ($)"))
# Out:
# [Text(0, 0.5, 'Prices ($)')]

# %%
# Overlay the visualizations for the bitstamp and coinbase DataFrames in one plot
# The plot should visualize the prices over the full lenth of the dataset
# Be sure to include the parameters: legend, figure size, title, and color and label
# YOUR CODE HERE

# This creates an overlay plot to show the difference between the Bitstamp's and Coinbase's Closing Prices with adding respective legends, 
# color coding the line graph as well as sizing it. Additionally, we made the line graph a bit transparent using 
# the alpha attribute so we can easily see both data, also adding y-axis label "Prices($)".

(bitstamp_sliced.plot(legend=True, kind="line", figsize=(15, 8), color=["red"], alpha=0.8, title= "Bitstamp vs. Coinbase", label="Bitstamp Close Price").set(ylabel="Prices ($)"))

(coinbase_sliced.plot(legend=True, kind="line", figsize=(15, 8), color=["blue"], alpha=0.5, label="Coinbase Close Price").set(ylabel="Prices ($)"))
# Out:
# [Text(0, 0.5, 'Prices ($)')]

# %%
# Using the loc and plot functions, create an overlay plot that visualizes 
# the price action of both DataFrames for a one month period early in the dataset
# Be sure to include the parameters: legend, figure size, title, and color and label
# YOUR CODE HERE

# This creates an overlay plot to show the difference between the Bitstamp's and Coinbase's Closing Prices for one month period early in the dataset, 
# with adding respective legends, color coding the line graph as well as sizing it. Additionally, we made the line graph a bit transparent 
# using the alpha attribute so we can easily see both data, also adding y-axis label "Prices($)".


(bitstamp_sliced.loc["2018-01-01 00:00" : "2018-02-01 23:59"].plot(legend=True, kind="line", figsize=(15, 8), color=["red"], alpha=0.8, title= "Bitstamp vs. Coinbase (Jan-1-2018 to Feb-1-2018)", label="Bitstamp Close Price").set(ylabel="Prices ($)"))

(coinbase_sliced.loc["2018-01-01 00:00" : "2018-02-01 23:59"].plot(legend=True, kind="line", figsize=(15, 8), color=["blue"], alpha=0.5, label="Coinbase Close Price").set(ylabel="Prices ($)"))
# Out:
# [Text(0, 0.5, 'Prices ($)')]

# %%
# Using the loc and plot functions, create an overlay plot that visualizes 
# the price action of both DataFrames for a one month period later in the dataset
# Be sure to include the parameters: legend, figure size, title, and color and label 
# YOUR CODE HERE

# This creates an overlay plot to show the difference between the Bitstamp's and Coinbase's Closing Prices for one month period later in the dataset, 
# with adding respective legends, color coding the line graph as well as sizing it. Additionally, we made the line graph a bit transparent 
# using the alpha attribute so we can easily see both data, also adding y-axis label "Prices($)".


(bitstamp_sliced.loc["2018-03-01 00:00" : "2018-04-01 23:59"].plot(legend=True, kind="line", figsize=(15, 8), color=["red"], alpha=0.8, title= "Bitstamp vs. Coinbase (Mar-1-2018 to Apr-1-2018)", label="Bitstamp Close Price").set(ylabel="Prices ($)"))

(coinbase_sliced.loc["2018-03-01 00:00" : "2018-04-01 23:59"].plot(legend=True, kind="line", figsize=(15, 8), color=["blue"], alpha=0.5, label="Coinbase Close Price").set(ylabel="Prices ($)"))
# Out:
# [Text(0, 0.5, 'Prices ($)')]

# %% [markdown]
# **Question** Based on the visualizations of the different time periods, has the degree of spread change as time progressed?
#
# **Answer:**
#
# I believe it changed. For the month of January, the prices of both Bitstamp and Coinbase had an average of USD 12750. But for the month of March, both Bitstamp and Coinbase were down, and even their average price were down to USD 9000. This shows that since Jan 2018, the price for both Bitstamp and Coinbase has been decreasing. However, we also notice on the graphs that it usually starts at higher price for at least the first half of the month, then the price decreases even more the second half of the month, and this is shown on both Jan-Feb 2018 scenatio, as well as Mar-Apr 2018 scenario.

# %% [markdown]
# ### Step 3: Focus Your Analysis on Specific Dates
#
# Focus your analysis on specific dates by completing the following steps:
#
# 1. Select three dates to evaluate for arbitrage profitability. Choose one date that’s early in the dataset, one from the middle of the dataset, and one from the later part of the time period.
#
# 2. For each of the three dates, generate the summary statistics and then create a box plot. This big-picture view is meant to help you gain a better understanding of the data before you perform your arbitrage calculations. As you compare the data, what conclusions can you draw?

# %%
# Create an overlay plot that visualizes the two dataframes over a period of one day early in the dataset. 
# Be sure that the plots include the parameters `legend`, `figsize`, `title`, `color` and `label` 
# YOUR CODE HERE

# This creates an overlay plot to show the difference between the Bitstamp's and Coinbase's Closing Prices for a one day period, early in the dataset, 
# with adding respective legends, color coding the line graph as well as sizing it. Additionally, we made the line graph a bit transparent 
# using the alpha attribute so we can easily see both data, also adding y-axis label "Prices($)".


(bitstamp_sliced.loc["2018-01-17"].plot(legend=True, kind="line", figsize=(15, 8), color=["red"], alpha=0.8, title= "Bitstamp vs. Coinbase (Jan-17-2018)", label="Bitstamp Close Price").set(ylabel="Prices ($)"))

(coinbase_sliced.loc["2018-01-17"].plot(legend=True, kind="line", figsize=(15, 8), color=["blue"], alpha=0.5, label="Coinbase Close Price").set(ylabel="Prices ($)"))
# Out:
# [Text(0, 0.5, 'Prices ($)')]

# %%
# Using the early date that you have selected, calculate the arbitrage spread 
# by subtracting the bitstamp lower closing prices from the coinbase higher closing prices

# This gets the arbitrage spread for a period early in the dataset.

arbitrage_spread_early = coinbase_sliced.loc["2018-01-17"] - bitstamp_sliced.loc["2018-01-17"]
arbitrage_spread_early
# Out:
# Timestamp
# 2018-01-17 00:00:00   -39.10
# 2018-01-17 00:01:00   -53.34
# 2018-01-17 00:02:00   -36.37
# 2018-01-17 00:03:00     7.09
# 2018-01-17 00:04:00   -41.11
#                        ...
# 2018-01-17 23:55:00   -27.46
# 2018-01-17 23:56:00   -28.95
# 2018-01-17 23:57:00   -37.62
# 2018-01-17 23:58:00   -18.49
# 2018-01-17 23:59:00   -23.38
# Name: Close, Length: 1440, dtype: float64

# %%
# Generate summary statistics for the early DataFrame
# YOUR CODE HERE

# This will describe the statistics of the arbitrage spread for the date early in the dataset.
arbitrage_spread_early.describe()
# Out:
# count    1440.000000
# mean       -0.291097
# std        46.607831
# min      -205.410000
# 25%       -24.427500
# 50%         0.010000
# 75%        25.995000
# max       190.220000
# Name: Close, dtype: float64

# %%
# Visualize the arbitrage spread from early in the dataset in a box plot
# YOUR CODE HERE

# This boxplot plots the arbitrage spread from early in the dataset which shows that the spread's median is at 0,
# our upper quartile is a little below 50, while our lower quartile is a little above -50. 
# Our upper whisker and lower whisker are at 100 and -100 respectively. Lastly, the black dots outside the whiskers represent outliers in this case.

arbitrage_spread_early.plot(kind="box", color="blue", title="Arbritrage Spread (Early)")
# Out:
# <AxesSubplot:title={'center':'Arbritrage Spread (Early)'}>

# %%
# Create an overlay plot that visualizes the two dataframes over a period of one day from the middle of the dataset. 
# Be sure that the plots include the parameters `legend`, `figsize`, `title`, `color` and `label` 
# YOUR CODE HERE

# This creates an overlay plot to show the difference between the Bitstamp's and Coinbase's Closing Prices for a one day period, middle of the dataset, 
# with adding respective legends, color coding the line graph as well as sizing it. Additionally, we made the line graph a bit transparent 
# using the alpha attribute so we can easily see both data, also adding y-axis label "Prices($)".

(bitstamp_sliced.loc["2018-02-24"].plot(legend=True, kind="line", figsize=(15, 8), color=["red"], alpha=0.8, title= "Bitstamp vs. Coinbase (Feb-24-2018)", label="Bitstamp Close Price").set(ylabel="Prices ($)"))

(coinbase_sliced.loc["2018-02-24"].plot(legend=True, kind="line", figsize=(15, 8), color=["blue"], alpha=0.5, label="Coinbase Close Price").set(ylabel="Prices ($)"))
# Out:
# [Text(0, 0.5, 'Prices ($)')]

# %%
# Using the date in the middle that you have selected, calculate the arbitrage spread 
# by subtracting the bitstamp lower closing prices from the coinbase higher closing prices

# This gets the arbitrage spread for a period middle in the dataset.
arbitrage_spread_middle = coinbase_sliced.loc["2018-02-24"] - bitstamp_sliced.loc["2018-02-24"]
arbitrage_spread_middle
# Out:
# Timestamp
# 2018-02-24 00:00:00   -24.00
# 2018-02-24 00:01:00   -30.08
# 2018-02-24 00:02:00   -29.60
# 2018-02-24 00:03:00   -39.71
# 2018-02-24 00:04:00   -24.81
#                        ...
# 2018-02-24 23:55:00   -15.00
# 2018-02-24 23:56:00    -6.97
# 2018-02-24 23:57:00   -20.69
# 2018-02-24 23:58:00    -7.41
# 2018-02-24 23:59:00   -13.31
# Name: Close, Length: 1440, dtype: float64

# %%
# Generate summary statistics 
# YOUR CODE HERE

# This generates the statistics for the middle arbitrage spread.
arbitrage_spread_middle.describe()
# Out:
# count    1437.000000
# mean        3.396131
# std        22.969472
# min       -50.180000
# 25%       -10.590000
# 50%        -0.010000
# 75%        12.120000
# max       121.320000
# Name: Close, dtype: float64

# %%
# Visualize the arbitrage spread from the middle of the dataset in a box plot
# YOUR CODE HERE


# This boxplot plots the arbitrage spread from middle of the dataset, which shows that the spread's median is at 0,
# our upper quartile is a around 10, while our lower quartile is a little below 0. 
# Our upper whisker is little below 50, while our lower whisker is above -50. Lastly, the black dots outside the whiskers represent outliers in this case.

arbitrage_spread_middle.plot(kind="box", color="blue", title="Arbritrage Spread (Middle)")
# Out:
# <AxesSubplot:title={'center':'Arbritrage Spread (Middle)'}>

# %%
# Create an overlay plot that visualizes the two dataframes over a period of one day from late in the dataset. 
# Be sure that the plots include the parameters `legend`, `figsize`, `title`, `color` and `label` 
# YOUR CODE HERE

# This creates an overlay plot to show the difference between the Bitstamp's and Coinbase's Closing Prices for a one day period, late of the dataset, 
# with adding respective legends, color coding the line graph as well as sizing it. Additionally, we made the line graph a bit transparent 
# using the alpha attribute so we can easily see both data, also adding y-axis label "Prices($)".

(bitstamp_sliced.loc["2018-03-26"].plot(legend=True, kind="line", figsize=(15, 8), color=["red"], alpha=0.8, title= "Bitstamp vs. Coinbase (Mar-26-2018)", label="Bitstamp Close Price").set(ylabel="Prices ($)"))
(coinbase_sliced.loc["2018-03-26"].plot(legend=True, kind="line", figsize=(15, 8), color=["blue"], alpha=0.5, label="Coinbase Close Price").set(ylabel="Prices ($)"))
# Out:
# [Text(0, 0.5, 'Prices ($)')]

# %%
# Using the date from the late that you have selected, calculate the arbitrage spread 
# by subtracting the bitstamp lower closing prices from the coinbase higher closing prices
arbitrage_spread_late = coinbase_sliced.loc["2018-03-26"] - bitstamp_sliced.loc["2018-03-26"]
arbitrage_spread_late
# Out:
# Timestamp
# 2018-03-26 00:00:00     6.21
# 2018-03-26 00:01:00     1.03
# 2018-03-26 00:02:00     3.96
# 2018-03-26 00:03:00     4.85
# 2018-03-26 00:04:00    11.75
#                        ...
# 2018-03-26 23:55:00   -17.89
# 2018-03-26 23:56:00     8.99
# 2018-03-26 23:57:00     4.60
# 2018-03-26 23:58:00   -11.54
# 2018-03-26 23:59:00    -0.34
# Name: Close, Length: 1440, dtype: float64

# %%
# Generate summary statistics for the late DataFrame
# YOUR CODE HERE
arbitrage_spread_late.describe()
# Out:
# count    1432.000000
# mean       -0.722193
# std         8.523060
# min       -32.040000
# 25%        -6.812500
# 50%        -0.730000
# 75%         4.965000
# max        35.070000
# Name: Close, dtype: float64

# %%
# Visualize the arbitrage spread from late in the dataset in a box plot

# This boxplot plots the arbitrage spread from late in the dataset which shows that the spread's median is at -0.73,
# our upper quartile is around 4, while our lower quartile is around -6. 
# Our upper whisker is little above 20, while our lower whisker is in between -20 and -30. Lastly, the black dots outside the whiskers represent outliers in this case.

arbitrage_spread_late.plot(kind="box", color="blue", title="Arbritrage Spread (Late)")
# Out:
# <AxesSubplot:title={'center':'Arbritrage Spread (Late)'}>

# %% [markdown]
# As you compare the data, what conclusions can you draw?

# %% [markdown]
# ### Step 4: Calculate the Arbitrage Profits
#
# Calculate the potential profits for each date that you selected in the previous section. Your goal is to determine whether arbitrage opportunities still exist in the Bitcoin market. Complete the following steps:
#
# 1. For each of the three dates, measure the arbitrage spread between the two exchanges by subtracting the lower-priced exchange from the higher-priced one. Then use a conditional statement to generate the summary statistics for each arbitrage_spread DataFrame, where the spread is greater than zero.
#
# 2. For each of the three dates, calculate the spread returns. To do so, divide the instances that have a positive arbitrage spread (that is, a spread greater than zero) by the price of Bitcoin from the exchange you’re buying on (that is, the lower-priced exchange). Review the resulting DataFrame.
#
# 3. For each of the three dates, narrow down your trading opportunities even further. To do so, determine the number of times your trades with positive returns exceed the 1% minimum threshold that you need to cover your costs.
#
# 4. Generate the summary statistics of your spread returns that are greater than 1%. How do the average returns compare among the three dates?
#
# 5. For each of the three dates, calculate the potential profit, in dollars, per trade. To do so, multiply the spread returns that were greater than 1% by the cost of what was purchased. Make sure to drop any missing values from the resulting DataFrame.
#
# 6. Generate the summary statistics, and plot the results for each of the three DataFrames.
#
# 7. Calculate the potential arbitrage profits that you can make on each day. To do so, sum the elements in the profit_per_trade DataFrame.
#
# 8. Using the `cumsum` function, plot the cumulative sum of each of the three DataFrames. Can you identify any patterns or trends in the profits across the three time periods?
#
# (NOTE: The starter code displays only one date. You'll want to do this analysis for two additional dates).

# %% [markdown]
# #### 1. For each of the three dates, measure the arbitrage spread between the two exchanges by subtracting the lower-priced exchange from the higher-priced one. Then use a conditional statement to generate the summary statistics for each arbitrage_spread DataFrame, where the spread is greater than zero.
#
# *NOTE*: For illustration, only one of the three dates is shown in the starter code below.

# %%
# For the date early in the dataset, measure the arbitrage spread between the two exchanges
# by subtracting the lower-priced exchange from the higher-priced one

# This gets the arbitrage spread for an early period of the dataset.
arbitrage_spread_early = coinbase_sliced.loc["2018-01-17"] - bitstamp_sliced.loc["2018-01-17"]

# Use a conditional statement to generate the summary statistics for each arbitrage_spread DataFrame
# YOUR CODE HERE
# This generates the statistics for the early period of arbitrage that are greater than 0.
arbitrage_spread_early[arbitrage_spread_early > 0].describe()
# Out:
# count    723.000000
# mean      33.601701
# std       29.109595
# min        0.010000
# 25%       12.940000
# 50%       25.910000
# 75%       46.005000
# max      190.220000
# Name: Close, dtype: float64

# %%
# This gets the arbitrage spread for a middle period of the dataset.
arbitrage_spread_middle = coinbase_sliced.loc['2018-02-24'] - bitstamp_sliced.loc['2018-02-24']

# Use a conditional statement to generate the summary statistics for each arbitrage_spread DataFrame
# This generates the statistics for the middle period of arbitrage that are greater than 0.
arbitrage_spread_middle[arbitrage_spread_middle > 0].describe()
# Out:
# count    713.000000
# mean      19.880351
# std       20.699851
# min        0.010000
# 25%        5.040000
# 50%       12.330000
# 75%       27.250000
# max      121.320000
# Name: Close, dtype: float64

# %%
# This gets the arbitrage spread for a late period of the dataset.
arbitrage_spread_late = coinbase_sliced.loc['2018-03-26'] - bitstamp_sliced.loc['2018-03-26']

# This generates the statistics for the late period of arbitrage that are greater than 0.
arbitrage_spread_late[arbitrage_spread_late > 0].describe()
# Out:
# count    651.000000
# mean       6.689247
# std        5.240159
# min        0.010000
# 25%        2.835000
# 50%        5.230000
# 75%        9.195000
# max       35.070000
# Name: Close, dtype: float64

# %% [markdown]
# #### 2. For each of the three dates, calculate the spread returns. To do so, divide the instances that have a positive arbitrage spread (that is, a spread greater than zero) by the price of Bitcoin from the exchange you’re buying on (that is, the lower-priced exchange). Review the resulting DataFrame.

# %%
# For the date early in the dataset, calculate the spread returns by dividing the instances when the arbitrage spread is positive (> 0) 
# by the price of Bitcoin from the exchange you are buying on (the lower-priced exchange).

# This shows the spread return for the early period of the dataset against the lower priced exchange, which is Bitstamp. 
# Anything that shows a positive value means there was a profit, and NaN values means it was a loss.
spread_return_early = arbitrage_spread_early[arbitrage_spread_early > 0] / bitstamp_sliced.loc["2018-01-17"]

# Review the spread return DataFrame
# YOUR CODE HERE

# This shows the top 10 values of the early period of the dataframe.
spread_return_early.head(10)
# Out:
# Timestamp
# 2018-01-17 00:00:00         NaN
# 2018-01-17 00:01:00         NaN
# 2018-01-17 00:02:00         NaN
# 2018-01-17 00:03:00    0.000637
# 2018-01-17 00:04:00         NaN
# 2018-01-17 00:05:00         NaN
# 2018-01-17 00:06:00         NaN
# 2018-01-17 00:07:00         NaN
# 2018-01-17 00:08:00    0.002826
# 2018-01-17 00:09:00    0.004773
# Name: Close, dtype: float64

# %%
# This shows the spread return for the middle period of the dataset against the lower priced exchange, which is Bitstamp. 

spread_return_middle = arbitrage_spread_middle[arbitrage_spread_middle > 0] / bitstamp_sliced.loc["2018-02-24"]

# Review the spread return DataFrame
# YOUR CODE HERE
# This shows the top 10 values of the middle period of the dataframe.
# This also shows that there were no profits generated.
spread_return_middle.head(10)
# Out:
# Timestamp
# 2018-02-24 00:00:00   NaN
# 2018-02-24 00:01:00   NaN
# 2018-02-24 00:02:00   NaN
# 2018-02-24 00:03:00   NaN
# 2018-02-24 00:04:00   NaN
# 2018-02-24 00:05:00   NaN
# 2018-02-24 00:06:00   NaN
# 2018-02-24 00:07:00   NaN
# 2018-02-24 00:08:00   NaN
# 2018-02-24 00:09:00   NaN
# Name: Close, dtype: float64

# %%
# This shows the spread return for the late period of the dataset against the lower priced exchange, which is Bitstamp. 
# It seems that on the late period of arbitrage spread, it had generated some profit.
spread_return_late = arbitrage_spread_late[arbitrage_spread_late > 0] / bitstamp_sliced.loc["2018-03-26"]

# Review the spread return DataFrame
# YOUR CODE HERE
# This shows the top 10 values of the late period of the dataframe.
spread_return_late.head(10)
# Out:
# Timestamp
# 2018-03-26 00:00:00    0.000738
# 2018-03-26 00:01:00    0.000122
# 2018-03-26 00:02:00    0.000470
# 2018-03-26 00:03:00    0.000576
# 2018-03-26 00:04:00    0.001395
# 2018-03-26 00:05:00    0.002551
# 2018-03-26 00:06:00    0.001742
# 2018-03-26 00:07:00    0.001861
# 2018-03-26 00:08:00    0.002449
# 2018-03-26 00:09:00    0.002117
# Name: Close, dtype: float64

# %% [markdown]
# #### 3. For each of the three dates, narrow down your trading opportunities even further. To do so, determine the number of times your trades with positive returns exceed the 1% minimum threshold that you need to cover your costs.

# %%
# For the date early in the dataset, determine the number of times your trades with positive returns 
# exceed the 1% minimum threshold (.01) that you need to cover your costs

# This generates the early period spread return that have positive trades, and are at least 1% to be able to cover the costs.
profitable_trades_early = spread_return_early[spread_return_early > .01]

# Review the first five profitable trades
# YOUR CODE HERE

# This shows the first 5 dataframe for the early period spread return trades that are at least 1%.
profitable_trades_early.head()
# Out:
# Timestamp
# 2018-01-17 04:45:00    0.010996
# 2018-01-17 04:46:00    0.013017
# 2018-01-17 04:47:00    0.013194
# 2018-01-17 04:48:00    0.012125
# 2018-01-17 04:49:00    0.017560
# Name: Close, dtype: float64

# %%
# This generates the middle period spread return that have positive trades, and are at least 1% to be able to cover the costs.
profitable_trades_middle = spread_return_middle[spread_return_middle > .01]

# Review the first five profitable trades
# YOUR CODE HERE

# This shows the first 3 dataframe for the middle period spread return trades that are at least 1%.
# It also means that there are only a total of 3 positive trades.
profitable_trades_middle.head()
# Out:
# Timestamp
# 2018-02-24 08:32:00    0.012726
# 2018-02-24 09:32:00    0.010974
# 2018-02-24 09:39:00    0.010431
# Name: Close, dtype: float64

# %%
# This generates the late period spread return that have positive trades, and are at least 1% to be able to cover the costs.
profitable_trades_late = spread_return_late[spread_return_late > .01]

# Review the first five profitable trades
# YOUR CODE HERE

# This shows that during the late period spread return, there are no trades that are at least 1%.
# but this doesn't mean that there weren't any positive trades.
profitable_trades_late.head()
# Out:
# Series([], Name: Close, dtype: float64)

# %% [markdown]
# #### 4. Generate the summary statistics of your spread returns that are greater than 1%. How do the average returns compare among the three dates?

# %%
# For the date early in the dataset, generate the summary statistics for the profitable trades
# or you trades where the spread returns are are greater than 1%
# YOUR CODE HERE

# This shows the statistics for the profitable trades in the early period of the dataset that are at least 1%.
profitable_trades_early.describe()
# Out:
# count    23.000000
# mean      0.012935
# std       0.002331
# min       0.010323
# 25%       0.011264
# 50%       0.012439
# 75%       0.013514
# max       0.018283
# Name: Close, dtype: float64

# %%
# This shows the statistics for the profitable trades in the middle period of the dataset that are at least 1%.
# In this case for the middle period, this shows that because there weren't any trades that are at least 1%, most of the 
# values on the statistics are NaN.
profitable_trades_middle.describe()
# Out:
# count    3.000000
# mean     0.011377
# std      0.001199
# min      0.010431
# 25%      0.010703
# 50%      0.010974
# 75%      0.011850
# max      0.012726
# Name: Close, dtype: float64

# %%
# This shows the statistics for the profitable trades in the late period of the dataset that are least 1%.
# In this case for the late period, this shows that because there weren't any trades that are at least 1%, most of the 
# values on the statistics are NaN.
profitable_trades_late.describe()
# Out:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: Close, dtype: float64

# %% [markdown]
# #### 5. For each of the three dates, calculate the potential profit, in dollars, per trade. To do so, multiply the spread returns that were greater than 1% by the cost of what was purchased. Make sure to drop any missing values from the resulting DataFrame.

# %%
# For the date early in the dataset, calculate the potential profit per trade in dollars 
# Multiply the profitable trades by the cost of the Bitcoin that was purchased

# This generates a early period dataframe with its profit per time period. 
profit_early = profitable_trades_early * bitstamp_sliced.loc["2018-01-17"]


# Drop any missing values from the profit DataFrame
# This will remove any NaN values in the early period of the dataframe.
profit_per_trade_early = profit_early.dropna()


# View the early profit DataFrame
# YOUR CODE HERE
# This views the early period of the dataframe after removing the NaN values.
profit_per_trade_early
# Out:
# Timestamp
# 2018-01-17 04:45:00    115.62
# 2018-01-17 04:46:00    136.68
# 2018-01-17 04:47:00    138.04
# 2018-01-17 04:48:00    126.54
# 2018-01-17 04:49:00    184.17
# 2018-01-17 04:51:00    107.36
# 2018-01-17 04:52:00    151.99
# 2018-01-17 04:53:00    190.22
# 2018-01-17 04:54:00    119.52
# 2018-01-17 04:55:00    126.79
# 2018-01-17 04:56:00    129.97
# 2018-01-17 05:07:00    168.28
# 2018-01-17 05:10:00    138.72
# 2018-01-17 05:11:00    129.03
# 2018-01-17 05:24:00    117.11
# 2018-01-17 05:26:00    110.18
# 2018-01-17 05:27:00    127.66
# 2018-01-17 05:46:00    118.39
# 2018-01-17 09:44:00    163.80
# 2018-01-17 13:14:00    132.51
# 2018-01-17 13:31:00    101.72
# 2018-01-17 13:34:00    108.71
# 2018-01-17 17:15:00    120.40
# Name: Close, dtype: float64

# %%
# This generates a middle period dataframe with its profit per time period. 
profit_middle = profitable_trades_middle * bitstamp_sliced.loc["2018-02-24"]

# Drop any missing values from the profit DataFrame
# This will remove any NaN values in the middle period of the dataframe.
profit_per_trade_middle = profit_middle.dropna()

# View the early profit DataFrame
# YOUR CODE HERE
# This views the middle period of the dataframe after removing the NaN values.
# But in this case, it doesn't seem that there was any profits for the middle period, hence 
# it didn't generate any data.
profit_per_trade_middle
# Out:
# Timestamp
# 2018-02-24 08:32:00    121.32
# 2018-02-24 09:32:00    107.00
# 2018-02-24 09:39:00    101.75
# Name: Close, dtype: float64

# %%
# This generates a late period dataframe with its profit per time period. 
profit_late = profitable_trades_late * bitstamp_sliced.loc["2018-03-26"]

# Drop any missing values from the profit DataFrame
# This will remove any NaN values in the late period of the dataframe.
profit_per_trade_late = profit_late.dropna()

# View the late profit DataFrame
# YOUR CODE HERE
# This views the late period of the dataframe after removing the NaN values.
# But in this case, it doesn't seem that there was any profits for the late period, hence 
# it didn't generate any data.
profit_per_trade_late
# Out:
# Series([], Name: Close, dtype: float64)

# %% [markdown]
# #### 6. Generate the summary statistics, and plot the results for each of the three DataFrames.

# %%
# Generate the summary statistics for the early profit per trade DataFrame
# YOUR CODE HERE

# This generates the statistics of early period dataframe.
profit_per_trade_early.describe()
# Out:
# count     23.000000
# mean     133.191739
# std       23.842599
# min      101.720000
# 25%      117.750000
# 50%      127.660000
# 75%      138.380000
# max      190.220000
# Name: Close, dtype: float64

# %%
# Plot the results for the early profit per trade DataFrame
# YOUR CODE HERE

# This plots the early profit per trade.
profit_per_trade_early.plot(kind="line", figsize=(15, 8), color=["red"], alpha=0.8, title= "Profit Per Trade- Early Period")
# Out:
# <AxesSubplot:title={'center':'Profit Per Trade- Early Period'}, xlabel='Timestamp'>

# %%
# This generates the statistics of middle period dataframe.
profit_per_trade_middle.describe()
# Out:
# count      3.000000
# mean     110.023333
# std       10.129246
# min      101.750000
# 25%      104.375000
# 50%      107.000000
# 75%      114.160000
# max      121.320000
# Name: Close, dtype: float64

# %%
# This plots the middle profit per trade.

profit_per_trade_middle.plot(kind="line", figsize=(15, 8), color=["red"], alpha=0.8, title= "Profit Per Trade- Middle Period")
# Out:
# <AxesSubplot:title={'center':'Profit Per Trade- Middle Period'}, xlabel='Timestamp'>

# %%
# This generates the statistics of late period dataframe.
profit_per_trade_late.describe()
# Out:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: Close, dtype: float64

# %%
# This plots the late profit per trade. However, nothing is shown since there was no profit that is at least 1%.
profit_per_trade_late.plot(kind="line", figsize=(15, 8), color=["red"], alpha=0.8, title= "Profit Per Trade- Late Period")
# Out:
# <AxesSubplot:title={'center':'Profit Per Trade- Late Period'}, xlabel='Timestamp'>

# %% [markdown]
# #### 7. Calculate the potential arbitrage profits that you can make on each day. To do so, sum the elements in the profit_per_trade DataFrame.

# %%
# Calculate the sum of the potential profits for the early profit per trade DataFrame
# YOUR CODE HERE

# This calculates the total profits from the early period of the dataset.
# Also, this means that the potential to make $3063 existed on a single day 
# by arbitraging between the two exchanges. 
profit_per_trade_early.sum()
# Out:
# 3063.409999999998

# %%
# This calculates the total profits from the middle period of the dataset.
# Also, this means that the potential to make $330 existed on a single day 
# by arbitraging between the two exchanges. 

profit_per_trade_middle.sum()
# Out:
# 330.0699999999997

# %%
# This calculates the total profits from the late period of the dataset.
# Also, this means that there was no profitable trades during the late period.

profit_per_trade_late.sum()
# Out:
# 0.0

# %% [markdown]
# #### 8. Using the `cumsum` function, plot the cumulative sum of each of the three DataFrames. Can you identify any patterns or trends in the profits across the three time periods?

# %%
# Use the cumsum function to calculate the cumulative profits over time for the early profit per trade DataFrame

# This generates the cumulative profit per day for the early period of the dataset to check 
# the progress of an investment over time.

cumulative_profit_early = profit_per_trade_early.cumsum()
cumulative_profit_early.head()
# Out:
# Timestamp
# 2018-01-17 04:45:00    115.62
# 2018-01-17 04:46:00    252.30
# 2018-01-17 04:47:00    390.34
# 2018-01-17 04:48:00    516.88
# 2018-01-17 04:49:00    701.05
# Name: Close, dtype: float64

# %%
# Plot the cumulative sum of profits for the early profit per trade DataFrame
# YOUR CODE HERE
# This plots the cumulative profits per treade of the early period of the dataset.
(cumulative_profit_early.plot(kind="line", figsize=(15, 8), color=["red"], alpha=0.8, title= "Cumulative Profit Per Trade- Early Period").set(ylabel="Prices ($)"))
# Out:
# [Text(0, 0.5, 'Prices ($)')]

# %%
# This generates the cumulative profit per day for the middle period of the dataset to check 
# the progress of an investment over time.

cumulative_profit_middle = profit_per_trade_middle.cumsum()
cumulative_profit_middle.head()
# Out:
# Timestamp
# 2018-02-24 08:32:00    121.32
# 2018-02-24 09:32:00    228.32
# 2018-02-24 09:39:00    330.07
# Name: Close, dtype: float64

# %%
# This plots the cumulative profits per treade of the middle period of the dataset.
(cumulative_profit_middle.plot(kind="line", figsize=(15, 8), color=["red"], alpha=0.8, title= "Cumulative Profit Per Trade- Middle Period").set(ylabel="Prices ($)"))
# Out:
# [Text(0, 0.5, 'Prices ($)')]

# %%
# This generates the cumulative profit per day for the late period of the dataset, however
# in this scenario, there was no profit during that day, hence there is nothing to total.

cumulative_profit_late = profit_per_trade_late.cumsum()
cumulative_profit_late.head()
# Out:
# Series([], Name: Close, dtype: float64)

# %%
# This plots the cumulative profits per treade of the late period of the dataset. 
# This shows that there was no cumulative profits to plot.
(cumulative_profit_late.plot(kind="line", figsize=(15, 8), color=["red"], alpha=0.8, title= "Cumulative Profit Per Trade- Late Period").set(ylabel="Prices ($)"))
# Out:
# [Text(0, 0.5, 'Prices ($)')]

# %% [markdown]
# **Question:** After reviewing the profit information across each date from the different time periods, can you identify any patterns or trends?
#
# **Answer:**
#
# After reviewing the profit information, we see that earlier in the period, our investment were profitable and that we are able to receive USD 3063 in just one day of trading, but in the succeeding months, we have seen lesser profits to no profits at all. As more people see the potential in making money in the arbitrage scene, eventually this type of trading causes profits to go down and will no longer be lucrative.
